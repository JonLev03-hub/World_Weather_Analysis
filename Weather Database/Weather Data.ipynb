# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import keys
import requests
import json
import time
from datetime import datetime
from scipy.stats import linregress
key = keys["weather_key"]
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + key

# %% [markdown]
# #### Generating weather Data
# The code below is used to generate 2000 random cities, then generate a list of non-duplicate cities, after that the code gathers weather data for the cities and exports that to a csv so you dont need to generate a new weather database file every time you use the code
#
# Skip this section of code if you already have a csv

# %%
# Generate random cords
lats = np.random.uniform(high = 90,low = -90, size = 2000)
lngs = np.random.uniform(high = 180,low = -180, size = 2000)
cords = zip(lats,lngs)

# %%
# convert the cords into cities and then add them to a list without any duplicates
cities = []
for cord in cords : 
    city = citipy.nearest_city(cord[0],cord[1]).city_name
                               
    if city not in cities:
         cities.append(city)

# %%
# Define where the city data will be listed
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print(f"City not found. Skipping... Error Code :{city_weather['cod']}")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")


# convert the dictionary to a dataframe 
city_data_df = pd.DataFrame(city_data)

# save the dataframe as a csv (so you dont need to load a new city list every time)
city_data_df.to_csv("weatherpy_database.csv",index_label="City_ID")
city_data_df
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | isangel
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | kudat
# Processing Record 5 of Set 1 | deogarh
# Processing Record 6 of Set 1 | rincon
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 8 of Set 1 | vao
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | langres
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | nizhneyansk
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | gisenyi
# Processing Record 17 of Set 1 | mbeya
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | teya
# Processing Record 20 of Set 1 | synya
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | san patricio
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | birao
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | deputatskiy
# Processing Record 31 of Set 1 | george
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | husavik
# Processing Record 34 of Set 1 | moron
# Processing Record 35 of Set 1 | te anau
# Processing Record 36 of Set 1 | dicabisagan
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | halifax
# Processing Record 39 of Set 1 | maloshuyka
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | sioux lookout
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | sergiyevsk
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | basco
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | williston
# Processing Record 3 of Set 2 | makakilo city
# Processing Record 4 of Set 2 | alta floresta
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | la ronge
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | soverato
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | non sang
# Processing Record 13 of Set 2 | port hedland
# Processing Record 14 of Set 2 | dawei
# Processing Record 15 of Set 2 | erenhot
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 20 of Set 2 | san quintin
# Processing Record 21 of Set 2 | tabialan
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 22 of Set 2 | sentyabrskiy
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | katha
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | bowen
# Processing Record 31 of Set 2 | plettenberg bay
# Processing Record 32 of Set 2 | agirish
# Processing Record 33 of Set 2 | sinop
# Processing Record 34 of Set 2 | poyarkovo
# Processing Record 35 of Set 2 | puerto escondido
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | rungata
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | kalmunai
# Processing Record 41 of Set 2 | tinjah
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 42 of Set 2 | khonsar
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 43 of Set 2 | manado
# Processing Record 44 of Set 2 | belyy yar
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | mayfield
# Processing Record 47 of Set 2 | camacha
# Processing Record 48 of Set 2 | maua
# Processing Record 49 of Set 2 | vanavara
# Processing Record 50 of Set 2 | albany
# Processing Record 1 of Set 3 | nabire
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | bulolo
# Processing Record 5 of Set 3 | petropavlovka
# Processing Record 6 of Set 3 | meulaboh
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | richmond
# Processing Record 9 of Set 3 | katherine
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | comodoro rivadavia
# Processing Record 12 of Set 3 | iquique
# Processing Record 13 of Set 3 | caravelas
# Processing Record 14 of Set 3 | taltal
# Processing Record 15 of Set 3 | tumannyy
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 16 of Set 3 | avera
# Processing Record 17 of Set 3 | kudahuvadhoo
# Processing Record 18 of Set 3 | bluff
# Processing Record 19 of Set 3 | vaitupu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 20 of Set 3 | chikola
# Processing Record 21 of Set 3 | boende
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | ribeira grande
# Processing Record 24 of Set 3 | katsuura
# Processing Record 25 of Set 3 | santa rosa
# Processing Record 26 of Set 3 | kutum
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | mecca
# Processing Record 30 of Set 3 | zhigansk
# Processing Record 31 of Set 3 | rapar
# Processing Record 32 of Set 3 | puerto del rosario
# Processing Record 33 of Set 3 | praia da vitoria
# Processing Record 34 of Set 3 | thai binh
# Processing Record 35 of Set 3 | pareora
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | baijiantan
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | yurla
# Processing Record 40 of Set 3 | hay river
# Processing Record 41 of Set 3 | yanam
# Processing Record 42 of Set 3 | ammokhorion
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | mwaro
# Processing Record 45 of Set 3 | saint anthony
# Processing Record 46 of Set 3 | ocean city
# Processing Record 47 of Set 3 | mersing
# Processing Record 48 of Set 3 | suslovo
# Processing Record 49 of Set 3 | tura
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | ciudad del maiz
# Processing Record 4 of Set 4 | tari
# Processing Record 5 of Set 4 | broken hill
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | dunedin
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | kostino
# Processing Record 12 of Set 4 | pacific grove
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | faranah
# Processing Record 15 of Set 4 | hazorasp
# Processing Record 16 of Set 4 | araouane
# Processing Record 17 of Set 4 | mareeba
# Processing Record 18 of Set 4 | kungurtug
# Processing Record 19 of Set 4 | vila velha
# Processing Record 20 of Set 4 | terney
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | miranda
# Processing Record 24 of Set 4 | tacub
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 29 of Set 4 | barbar
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 30 of Set 4 | bilibino
# Processing Record 31 of Set 4 | amapa
# Processing Record 32 of Set 4 | eureka
# Processing Record 33 of Set 4 | karratha
# Processing Record 34 of Set 4 | tommot
# Processing Record 35 of Set 4 | brae
# Processing Record 36 of Set 4 | murgab
# Processing Record 37 of Set 4 | rokytnice nad jizerou
# Processing Record 38 of Set 4 | azare
# Processing Record 39 of Set 4 | mehamn
# Processing Record 40 of Set 4 | batticaloa
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | lata
# Processing Record 43 of Set 4 | kirakira
# Processing Record 44 of Set 4 | mawlaik
# Processing Record 45 of Set 4 | dickson
# Processing Record 46 of Set 4 | teberda
# Processing Record 47 of Set 4 | sorland
# Processing Record 48 of Set 4 | aksha
# Processing Record 49 of Set 4 | hobart
# Processing Record 50 of Set 4 | san policarpo
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | palmas de monte alto
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | kununurra
# Processing Record 5 of Set 5 | dakar
# Processing Record 6 of Set 5 | isiro
# Processing Record 7 of Set 5 | juneau
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | svetlogorsk
# Processing Record 10 of Set 5 | peschanokopskoye
# Processing Record 11 of Set 5 | rapid valley
# Processing Record 12 of Set 5 | bonavista
# Processing Record 13 of Set 5 | bereda
# Processing Record 14 of Set 5 | kalangala
# Processing Record 15 of Set 5 | los llanos de aridane
# Processing Record 16 of Set 5 | bafang
# Processing Record 17 of Set 5 | palmer
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | ambunti
# Processing Record 20 of Set 5 | tuatapere
# Processing Record 21 of Set 5 | umm lajj
# Processing Record 22 of Set 5 | jian
# Processing Record 23 of Set 5 | sergeyevka
# Processing Record 24 of Set 5 | kasongo
# Processing Record 25 of Set 5 | jiazi
# Processing Record 26 of Set 5 | golden
# Processing Record 27 of Set 5 | sabha
# Processing Record 28 of Set 5 | mezen
# Processing Record 29 of Set 5 | gat
# Processing Record 30 of Set 5 | chuy
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | ruatoria
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 33 of Set 5 | saldanha
# Processing Record 34 of Set 5 | el seibo
# Processing Record 35 of Set 5 | the valley
# Processing Record 36 of Set 5 | raudeberg
# Processing Record 37 of Set 5 | majenang
# Processing Record 38 of Set 5 | bubaque
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | quixeramobim
# Processing Record 42 of Set 5 | sayyan
# Processing Record 43 of Set 5 | pochutla
# Processing Record 44 of Set 5 | umzimvubu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 45 of Set 5 | poum
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 47 of Set 5 | ada
# Processing Record 48 of Set 5 | buariki
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 49 of Set 5 | kazalinsk
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 50 of Set 5 | nova borova
# Processing Record 1 of Set 6 | hasaki
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | belushya guba
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 4 of Set 6 | nihommatsu
# Processing Record 5 of Set 6 | saint-pierre
# Processing Record 6 of Set 6 | dolbeau
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 7 of Set 6 | tual
# Processing Record 8 of Set 6 | inta
# Processing Record 9 of Set 6 | vardo
# Processing Record 10 of Set 6 | skagastrond
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 11 of Set 6 | turukhansk
# Processing Record 12 of Set 6 | wana
# Processing Record 13 of Set 6 | helong
# Processing Record 14 of Set 6 | awbari
# Processing Record 15 of Set 6 | lebu
# Processing Record 16 of Set 6 | acapulco
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | tanggu
# Processing Record 19 of Set 6 | attawapiskat
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 20 of Set 6 | yerofey pavlovich
# Processing Record 21 of Set 6 | grand gaube
# Processing Record 22 of Set 6 | nanortalik
# Processing Record 23 of Set 6 | boyolangu
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | kargasok
# Processing Record 26 of Set 6 | puerto carreno
# Processing Record 27 of Set 6 | biak
# Processing Record 28 of Set 6 | mentok
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 29 of Set 6 | seydisehir
# Processing Record 30 of Set 6 | enid
# Processing Record 31 of Set 6 | sorong
# Processing Record 32 of Set 6 | saint-joseph
# Processing Record 33 of Set 6 | rorvik
# Processing Record 34 of Set 6 | provideniya
# Processing Record 35 of Set 6 | sao raimundo nonato
# Processing Record 36 of Set 6 | bow island
# Processing Record 37 of Set 6 | leningradskiy
# Processing Record 38 of Set 6 | tulsipur
# Processing Record 39 of Set 6 | toliary
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 40 of Set 6 | turtas
# Processing Record 41 of Set 6 | labutta
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 42 of Set 6 | vung tau
# Processing Record 43 of Set 6 | mahebourg
# Processing Record 44 of Set 6 | mahaicony
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 45 of Set 6 | narsaq
# Processing Record 46 of Set 6 | zilair
# Processing Record 47 of Set 6 | brownwood
# Processing Record 48 of Set 6 | carnarvon
# Processing Record 49 of Set 6 | lahat
# Processing Record 50 of Set 6 | ostrovnoy
# Processing Record 1 of Set 7 | fernan-nunez
# Processing Record 2 of Set 7 | pucallpa
# Processing Record 3 of Set 7 | lasa
# Processing Record 4 of Set 7 | chake chake
# Processing Record 5 of Set 7 | pevek
# Processing Record 6 of Set 7 | bogorodskoye
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | boa vista
# Processing Record 9 of Set 7 | ahlat
# Processing Record 10 of Set 7 | cap-aux-meules
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | poltavka
# Processing Record 13 of Set 7 | bababe
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 14 of Set 7 | vilhena
# Processing Record 15 of Set 7 | coquimbo
# Processing Record 16 of Set 7 | hervey bay
# Processing Record 17 of Set 7 | senneterre
# Processing Record 18 of Set 7 | nemuro
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | antalaha
# Processing Record 21 of Set 7 | bereznik
# Processing Record 22 of Set 7 | ust-ishim
# Processing Record 23 of Set 7 | agua branca
# Processing Record 24 of Set 7 | mendahara
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 25 of Set 7 | atar
# Processing Record 26 of Set 7 | clyde river
# Processing Record 27 of Set 7 | adrar
# Processing Record 28 of Set 7 | aksarka
# Processing Record 29 of Set 7 | shasta lake
# Processing Record 30 of Set 7 | saint combs
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 31 of Set 7 | richards bay
# Processing Record 32 of Set 7 | gaozhou
# Processing Record 33 of Set 7 | sao joao da barra
# Processing Record 34 of Set 7 | lowestoft
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | karamea
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 37 of Set 7 | llanes
# Processing Record 38 of Set 7 | voh
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | encruzilhada
# Processing Record 41 of Set 7 | hambantota
# Processing Record 42 of Set 7 | zhob
# Processing Record 43 of Set 7 | orasac
# Processing Record 44 of Set 7 | vavozh
# Processing Record 45 of Set 7 | mogok
# Processing Record 46 of Set 7 | karauzyak
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 47 of Set 7 | douglas
# Processing Record 48 of Set 7 | iqaluit
# Processing Record 49 of Set 7 | pierre
# Processing Record 50 of Set 7 | warqla
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 1 of Set 8 | wanning
# Processing Record 2 of Set 8 | altay
# Processing Record 3 of Set 8 | nome
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | cayenne
# Processing Record 6 of Set 8 | shakhtinsk
# Processing Record 7 of Set 8 | ambulu
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | laguna
# Processing Record 10 of Set 8 | oktyabrskoye
# Processing Record 11 of Set 8 | lukang
# Processing Record 12 of Set 8 | polovinnoye
# Processing Record 13 of Set 8 | marsh harbour
# Processing Record 14 of Set 8 | plock
# Processing Record 15 of Set 8 | portland
# Processing Record 16 of Set 8 | marienburg
# Processing Record 17 of Set 8 | kalabo
# Processing Record 18 of Set 8 | lahij
# Processing Record 19 of Set 8 | one hundred mile house
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 20 of Set 8 | sokolovyy
# Processing Record 21 of Set 8 | necochea
# Processing Record 22 of Set 8 | yarega
# Processing Record 23 of Set 8 | nuuk
# Processing Record 24 of Set 8 | beloha
# Processing Record 25 of Set 8 | mabay
# Processing Record 26 of Set 8 | amderma
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 27 of Set 8 | south lake tahoe
# Processing Record 28 of Set 8 | puerto ayacucho
# Processing Record 29 of Set 8 | sakakah
# Processing Record 30 of Set 8 | puerto leguizamo
# Processing Record 31 of Set 8 | tirumullaivasal
# Processing Record 32 of Set 8 | lorengau
# Processing Record 33 of Set 8 | meadow lake
# Processing Record 34 of Set 8 | ekhabi
# Processing Record 35 of Set 8 | linxia
# Processing Record 36 of Set 8 | sitka
# Processing Record 37 of Set 8 | bertoua
# Processing Record 38 of Set 8 | vila franca do campo
# Processing Record 39 of Set 8 | aswan
# Processing Record 40 of Set 8 | benguela
# Processing Record 41 of Set 8 | tazmalt
# Processing Record 42 of Set 8 | qaqortoq
# Processing Record 43 of Set 8 | grand centre
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 44 of Set 8 | kahului
# Processing Record 45 of Set 8 | souillac
# Processing Record 46 of Set 8 | ucluelet
# Processing Record 47 of Set 8 | chancay
# Processing Record 48 of Set 8 | maldonado
# Processing Record 49 of Set 8 | dingle
# Processing Record 50 of Set 8 | zhuhai
# Processing Record 1 of Set 9 | laranjeiras do sul
# Processing Record 2 of Set 9 | progreso
# Processing Record 3 of Set 9 | marzuq
# Processing Record 4 of Set 9 | kruisfontein
# Processing Record 5 of Set 9 | pankrushikha
# Processing Record 6 of Set 9 | kangaatsiaq
# Processing Record 7 of Set 9 | amarante do maranhao
# Processing Record 8 of Set 9 | kokopo
# Processing Record 9 of Set 9 | cedar city
# Processing Record 10 of Set 9 | puerto penasco
# Processing Record 11 of Set 9 | birjand
# Processing Record 12 of Set 9 | pangnirtung
# Processing Record 13 of Set 9 | berezovyy
# Processing Record 14 of Set 9 | shingu
# Processing Record 15 of Set 9 | paita
# Processing Record 16 of Set 9 | nawabganj
# Processing Record 17 of Set 9 | balkhash
# Processing Record 18 of Set 9 | phalaborwa
# Processing Record 19 of Set 9 | buala
# Processing Record 20 of Set 9 | sheridan
# Processing Record 21 of Set 9 | astoria
# Processing Record 22 of Set 9 | lolua
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 23 of Set 9 | minab
# Processing Record 24 of Set 9 | pangody
# Processing Record 25 of Set 9 | banyo
# Processing Record 26 of Set 9 | padilla
# Processing Record 27 of Set 9 | krasnovishersk
# Processing Record 28 of Set 9 | areia branca
# Processing Record 29 of Set 9 | sabang
# Processing Record 30 of Set 9 | saleaula
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 31 of Set 9 | hurghada
# Processing Record 32 of Set 9 | dzhubga
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | nepomuceno
# Processing Record 35 of Set 9 | russell
# Processing Record 36 of Set 9 | atasu
# Processing Record 37 of Set 9 | kontagora
# Processing Record 38 of Set 9 | ancud
# Processing Record 39 of Set 9 | garachine
# Processing Record 40 of Set 9 | robertsport
# Processing Record 41 of Set 9 | ahipara
# Processing Record 42 of Set 9 | remedios
# Processing Record 43 of Set 9 | atchison
# Processing Record 44 of Set 9 | vrangel
# Processing Record 45 of Set 9 | kosa
# Processing Record 46 of Set 9 | flagstaff
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | mount isa
# Processing Record 49 of Set 9 | eregli
# Processing Record 50 of Set 9 | srednekolymsk
# Processing Record 1 of Set 10 | saint-raymond
# Processing Record 2 of Set 10 | vostochnyy
# Processing Record 3 of Set 10 | los lunas
# Processing Record 4 of Set 10 | ketchikan
# Processing Record 5 of Set 10 | padang
# Processing Record 6 of Set 10 | el salto
# Processing Record 7 of Set 10 | khasan
# Processing Record 8 of Set 10 | erzin
# Processing Record 9 of Set 10 | menongue
# Processing Record 10 of Set 10 | stari banovci
# Processing Record 11 of Set 10 | harqalah
# Processing Record 12 of Set 10 | riyadh
# Processing Record 13 of Set 10 | nadym
# Processing Record 14 of Set 10 | resplendor
# Processing Record 15 of Set 10 | illapel
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | grand river south east
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 18 of Set 10 | almaznyy
# Processing Record 19 of Set 10 | walvis bay
# Processing Record 20 of Set 10 | mitu
# Processing Record 21 of Set 10 | never
# Processing Record 22 of Set 10 | mombetsu
# Processing Record 23 of Set 10 | balimo
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 24 of Set 10 | topeka
# Processing Record 25 of Set 10 | shellbrook
# Processing Record 26 of Set 10 | baruun-urt
# Processing Record 27 of Set 10 | syamzha
# Processing Record 28 of Set 10 | manzhouli
# Processing Record 29 of Set 10 | pinawa
# Processing Record 30 of Set 10 | sambava
# Processing Record 31 of Set 10 | oktyabrsk
# Processing Record 32 of Set 10 | gwadar
# Processing Record 33 of Set 10 | coxim
# Processing Record 34 of Set 10 | faya
# Processing Record 35 of Set 10 | eirunepe
# Processing Record 36 of Set 10 | de-kastri
# Processing Record 37 of Set 10 | bardiyah
# Processing Record 38 of Set 10 | zarechnyy
# Processing Record 39 of Set 10 | lexington
# Processing Record 40 of Set 10 | longkou
# Processing Record 41 of Set 10 | bolobo
# Processing Record 42 of Set 10 | taoudenni
# Processing Record 43 of Set 10 | matamoros
# Processing Record 44 of Set 10 | berlevag
# Processing Record 45 of Set 10 | laredo
# Processing Record 46 of Set 10 | katubao
# Processing Record 47 of Set 10 | yukon
# Processing Record 48 of Set 10 | montepuez
# Processing Record 49 of Set 10 | tessalit
# Processing Record 50 of Set 10 | ngukurr
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 1 of Set 11 | ojinaga
# Processing Record 2 of Set 11 | sola
# Processing Record 3 of Set 11 | sorvag
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 4 of Set 11 | bitung
# Processing Record 5 of Set 11 | port arthur
# Processing Record 6 of Set 11 | xian
# Processing Record 7 of Set 11 | udachnyy
# Processing Record 8 of Set 11 | karaul
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 9 of Set 11 | henties bay
# Processing Record 10 of Set 11 | oussouye
# Processing Record 11 of Set 11 | nelson bay
# Processing Record 12 of Set 11 | makhalino
# Processing Record 13 of Set 11 | andijon
# Processing Record 14 of Set 11 | chernyshevskiy
# Processing Record 15 of Set 11 | champerico
# Processing Record 16 of Set 11 | togur
# Processing Record 17 of Set 11 | boras
# Processing Record 18 of Set 11 | haapu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 19 of Set 11 | labuhan
# Processing Record 20 of Set 11 | havelock
# Processing Record 21 of Set 11 | poli
# Processing Record 22 of Set 11 | marcona
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 23 of Set 11 | aklavik
# Processing Record 24 of Set 11 | ayan
# Processing Record 25 of Set 11 | bud
# Processing Record 26 of Set 11 | nchelenge
# Processing Record 27 of Set 11 | kita
# Processing Record 28 of Set 11 | japura
# Processing Record 29 of Set 11 | hanesti
# Processing Record 30 of Set 11 | batemans bay
# Processing Record 31 of Set 11 | khromtau
# Processing Record 32 of Set 11 | gornyy
# Processing Record 33 of Set 11 | fort nelson
# Processing Record 34 of Set 11 | merrill
# Processing Record 35 of Set 11 | huarmey
# Processing Record 36 of Set 11 | darhan
# Processing Record 37 of Set 11 | coulommiers
# Processing Record 38 of Set 11 | sangueya
# Processing Record 39 of Set 11 | thinadhoo
# Processing Record 40 of Set 11 | vegueta
# Processing Record 41 of Set 11 | kieta
# Processing Record 42 of Set 11 | nsanje
# Processing Record 43 of Set 11 | chitral
# Processing Record 44 of Set 11 | ridgecrest
# Processing Record 45 of Set 11 | rampur
# Processing Record 46 of Set 11 | mustasaari
# Processing Record 47 of Set 11 | bumba
# Processing Record 48 of Set 11 | valparaiso
# Processing Record 49 of Set 11 | okahandja
# Processing Record 50 of Set 11 | bayir
# Processing Record 1 of Set 12 | rocha
# Processing Record 2 of Set 12 | churapcha
# Processing Record 3 of Set 12 | akyab
# Processing Record 4 of Set 12 | malinta
# Processing Record 5 of Set 12 | filadelfia
# Processing Record 6 of Set 12 | along
# Processing Record 7 of Set 12 | shache
# Processing Record 8 of Set 12 | takoradi
# Processing Record 9 of Set 12 | moranbah
# Processing Record 10 of Set 12 | okhotsk
# Processing Record 11 of Set 12 | tabuk
# Processing Record 12 of Set 12 | cam ranh
# Processing Record 13 of Set 12 | dezful
# Processing Record 14 of Set 12 | valdivia
# Processing Record 15 of Set 12 | chongoyape
# Processing Record 16 of Set 12 | palana
# Processing Record 17 of Set 12 | sal rei
# Processing Record 18 of Set 12 | staryy krym
# Processing Record 19 of Set 12 | monroe
# Processing Record 20 of Set 12 | ridgeland
# Processing Record 21 of Set 12 | verkhniy ufaley
# Processing Record 22 of Set 12 | coruripe
# Processing Record 23 of Set 12 | urumqi
# Processing Record 24 of Set 12 | vavuniya
# Processing Record 25 of Set 12 | lieksa
# Processing Record 26 of Set 12 | beroroha
# Processing Record 27 of Set 12 | sumter
# Processing Record 28 of Set 12 | samfya
# Processing Record 29 of Set 12 | taylorville
# Processing Record 30 of Set 12 | iralaya
# Processing Record 31 of Set 12 | road town
# Processing Record 32 of Set 12 | blythe
# Processing Record 33 of Set 12 | torit
# Processing Record 34 of Set 12 | fram
# Processing Record 35 of Set 12 | mana
# Processing Record 36 of Set 12 | abhar
# Processing Record 37 of Set 12 | bredy
# Processing Record 38 of Set 12 | starkville
# Processing Record 39 of Set 12 | butler
# Processing Record 40 of Set 12 | tazovskiy
# Processing Record 41 of Set 12 | fortuna
# Processing Record 42 of Set 12 | manzanillo
# Processing Record 43 of Set 12 | pavino
# Processing Record 44 of Set 12 | rio grande
# Processing Record 45 of Set 12 | rio cuarto
# Processing Record 46 of Set 12 | algiers
# Processing Record 47 of Set 12 | shirokiy
# Processing Record 48 of Set 12 | poddorye
# Processing Record 49 of Set 12 | huazolotitlan
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 50 of Set 12 | barroualie
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 1 of Set 13 | kenora
# Processing Record 2 of Set 13 | summerville
# Processing Record 3 of Set 13 | antofagasta
# Processing Record 4 of Set 13 | marsa matruh
# Processing Record 5 of Set 13 | marathopolis
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 6 of Set 13 | port blair
# Processing Record 7 of Set 13 | tezu
# Processing Record 8 of Set 13 | kamenka
# Processing Record 9 of Set 13 | pundaguitan
# Processing Record 10 of Set 13 | mount gambier
# Processing Record 11 of Set 13 | verkhnyaya inta
# Processing Record 12 of Set 13 | itarema
# Processing Record 13 of Set 13 | sakaiminato
# Processing Record 14 of Set 13 | diban
# Processing Record 15 of Set 13 | coahuayana
# Processing Record 16 of Set 13 | khonuu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 17 of Set 13 | port-cartier
# Processing Record 18 of Set 13 | tabatinga
# Processing Record 19 of Set 13 | aguas vermelhas
# Processing Record 20 of Set 13 | yar-sale
# Processing Record 21 of Set 13 | alnashi
# Processing Record 22 of Set 13 | ahuimanu
# Processing Record 23 of Set 13 | dembi dolo
# Processing Record 24 of Set 13 | eyl
# Processing Record 25 of Set 13 | aykhal
# Processing Record 26 of Set 13 | tambopata
# Processing Record 27 of Set 13 | codrington
# Processing Record 28 of Set 13 | matara
# Processing Record 29 of Set 13 | yeppoon
# Processing Record 30 of Set 13 | jalandhar
# Processing Record 31 of Set 13 | bosaso
# Processing Record 32 of Set 13 | panzhihua
# Processing Record 33 of Set 13 | auki
# Processing Record 34 of Set 13 | saint-georges
# Processing Record 35 of Set 13 | lithgow
# Processing Record 36 of Set 13 | jalu
# Processing Record 37 of Set 13 | klaksvik
# Processing Record 38 of Set 13 | shimoda
# Processing Record 39 of Set 13 | paamiut
# Processing Record 40 of Set 13 | baykit
# Processing Record 41 of Set 13 | mahwa
# Processing Record 42 of Set 13 | laela
# Processing Record 43 of Set 13 | tobol
# Processing Record 44 of Set 13 | rawson
# Processing Record 45 of Set 13 | buraydah
# Processing Record 46 of Set 13 | malwan
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 47 of Set 13 | soyo
# Processing Record 48 of Set 13 | eyemouth
# Processing Record 49 of Set 13 | sattahip
# Processing Record 50 of Set 13 | tamandare
# Processing Record 1 of Set 14 | tsagan aman
# Processing Record 2 of Set 14 | morinville
# Processing Record 3 of Set 14 | kavaratti
# Processing Record 4 of Set 14 | opuwo
# Processing Record 5 of Set 14 | kingisepp
# Processing Record 6 of Set 14 | lethem
# Processing Record 7 of Set 14 | sur
# Processing Record 8 of Set 14 | quatre cocos
# Processing Record 9 of Set 14 | ust-kamchatsk
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 10 of Set 14 | kizukuri
# Processing Record 11 of Set 14 | buzmeyin
# Processing Record 12 of Set 14 | fushan
# Processing Record 13 of Set 14 | qasigiannguit
# Processing Record 14 of Set 14 | berbera
# Processing Record 15 of Set 14 | tabou
# Processing Record 16 of Set 14 | ugoofaaru
# Processing Record 17 of Set 14 | penzance
# Processing Record 18 of Set 14 | guichicovi
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 19 of Set 14 | prince rupert
# Processing Record 20 of Set 14 | kodinsk
# Processing Record 21 of Set 14 | port macquarie
# Processing Record 22 of Set 14 | mutsamudu
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 23 of Set 14 | shenjiamen
# Processing Record 24 of Set 14 | chapais
# Processing Record 25 of Set 14 | rabo de peixe
# Processing Record 26 of Set 14 | severobaykalsk
# Processing Record 27 of Set 14 | pignon
# Processing Record 28 of Set 14 | virar
# Processing Record 29 of Set 14 | ahtopol
# Processing Record 30 of Set 14 | nosy varika
# Processing Record 31 of Set 14 | mayo
# Processing Record 32 of Set 14 | abu dhabi
# Processing Record 33 of Set 14 | maksatikha
# Processing Record 34 of Set 14 | khoy
# Processing Record 35 of Set 14 | champawat
# Processing Record 36 of Set 14 | ulaangom
# Processing Record 37 of Set 14 | tungor
# Processing Record 38 of Set 14 | marau
# Processing Record 39 of Set 14 | ladario
# Processing Record 40 of Set 14 | slavutych
# Processing Record 41 of Set 14 | tecoanapa
# Processing Record 42 of Set 14 | nagato
# Processing Record 43 of Set 14 | nyzhnya duvanka
# Processing Record 44 of Set 14 | nantucket
# Processing Record 45 of Set 14 | ordu
# Processing Record 46 of Set 14 | waitati
# Processing Record 47 of Set 14 | xingyi
# Processing Record 48 of Set 14 | oktyabrskiy
# Processing Record 49 of Set 14 | kaeo
# Processing Record 50 of Set 14 | pervomaysk
# Processing Record 1 of Set 15 | general roca
# Processing Record 2 of Set 15 | ust-nera
# Processing Record 3 of Set 15 | tres arroyos
# Processing Record 4 of Set 15 | port hueneme
# Processing Record 5 of Set 15 | jurm
# Processing Record 6 of Set 15 | mogadishu
# Processing Record 7 of Set 15 | kloulklubed
# Processing Record 8 of Set 15 | tonekabon
# Processing Record 9 of Set 15 | moose factory
# Processing Record 10 of Set 15 | flinders
# Processing Record 11 of Set 15 | peterhead
# Processing Record 12 of Set 15 | karakose
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 13 of Set 15 | barsovo
# Processing Record 14 of Set 15 | ilo
# Processing Record 15 of Set 15 | vestmannaeyjar
# Processing Record 16 of Set 15 | whitianga
# Processing Record 17 of Set 15 | harur
# Processing Record 18 of Set 15 | port-gentil
# Processing Record 19 of Set 15 | goure
# Processing Record 20 of Set 15 | mehran
# Processing Record 21 of Set 15 | okha
# Processing Record 22 of Set 15 | vysoke
# Processing Record 23 of Set 15 | nouadhibou
# Processing Record 24 of Set 15 | x-can
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 25 of Set 15 | belmonte
# Processing Record 26 of Set 15 | varna
# Processing Record 27 of Set 15 | ust-maya
# Processing Record 28 of Set 15 | chagda
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 29 of Set 15 | estelle
# Processing Record 30 of Set 15 | melchor de mencos
# Processing Record 31 of Set 15 | kenai
# Processing Record 32 of Set 15 | goderich
# Processing Record 33 of Set 15 | broome
# Processing Record 34 of Set 15 | riverton
# Processing Record 35 of Set 15 | uyuni
# Processing Record 36 of Set 15 | dryden
# Processing Record 37 of Set 15 | cizre
# Processing Record 38 of Set 15 | biloela
# Processing Record 39 of Set 15 | skalistyy
# City not found. Skipping... Error Code :404
# Api response = {'cod': '404', 'message': 'city not found'}
# Processing Record 40 of Set 15 | miri
# Processing Record 41 of Set 15 | haines junction
# Processing Record 42 of Set 15 | gizo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Mataura      NZ -46.1927  168.8643     49.48        78
# 1            Isangel      VU -19.5500  169.2667     74.05        87
# 2         Nikolskoye      RU  59.7035   30.7861     46.40        94
# 3              Kudat      MY   6.8837  116.8477     77.99        86
# 4            Deogarh      IN  21.5333   84.7333     67.84        74
# ..               ...     ...      ...       ...       ...       ...
# 677            Cizre      TR  37.3272   42.1903     69.39        49
# 678          Biloela      AU -24.4167  150.5000     62.94        85
# 679             Miri      MY   4.4148  114.0089     77.14       100
# 680  Haines Junction      CA  60.7522 -137.5108     21.15        86
# 681             Gizo      SB  -8.1030  156.8419     82.31        70
#
#      Cloudiness  Wind Speed       Description                 Date
# 0           100        0.43   overcast clouds  2021-11-04 19:11:39
# 1            89       14.34   overcast clouds  2021-11-04 19:11:39
# 2            26        6.91  scattered clouds  2021-11-04 19:09:27
# 3            86        2.53   overcast clouds  2021-11-04 19:11:39
# 4             4        2.08         clear sky  2021-11-04 19:11:40
# ..          ...         ...               ...                  ...
# 677           0        5.53         clear sky  2021-11-04 19:28:55
# 678          56        4.45     broken clouds  2021-11-04 19:28:55
# 679          40        3.44        light rain  2021-11-04 19:28:55
# 680          83        0.00     broken clouds  2021-11-04 19:28:56
# 681          99       13.09   overcast clouds  2021-11-04 19:28:56
#
# [682 rows x 10 columns]

# %%
# convert the dictionary to a dataframe 
city_data_df = pd.DataFrame(city_data)

# save the dataframe as a csv (so you dont need to load a new city list every time)
city_data_df.to_csv("weatherpy_database.csv",index_label="City_ID")

# %% [markdown]
# #### Analyzing data
# Below the code will use the csv produced above to do analysis and visualizations

# %%
# Load the city_data_df from the csv and look at it 
city_data_df = pd.read_csv("weatherpy_database.csv",index_col = "City_ID")
city_data_df
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                Mataura      NZ -46.1927  168.8643     49.48        78
# 1                Isangel      VU -19.5500  169.2667     74.05        87
# 2             Nikolskoye      RU  59.7035   30.7861     46.40        94
# 3                  Kudat      MY   6.8837  116.8477     77.99        86
# 4                Deogarh      IN  21.5333   84.7333     67.84        74
# ...                  ...     ...      ...       ...       ...       ...
# 677                Cizre      TR  37.3272   42.1903     69.39        49
# 678              Biloela      AU -24.4167  150.5000     62.94        85
# 679                 Miri      MY   4.4148  114.0089     77.14       100
# 680      Haines Junction      CA  60.7522 -137.5108     21.15        86
# 681                 Gizo      SB  -8.1030  156.8419     82.31        70
#
#          Cloudiness  Wind Speed       Description                 Date
# City_ID
# 0               100        0.43   overcast clouds  2021-11-04 19:11:39
# 1                89       14.34   overcast clouds  2021-11-04 19:11:39
# 2                26        6.91  scattered clouds  2021-11-04 19:09:27
# 3                86        2.53   overcast clouds  2021-11-04 19:11:39
# 4                 4        2.08         clear sky  2021-11-04 19:11:40
# ...             ...         ...               ...                  ...
# 677               0        5.53         clear sky  2021-11-04 19:28:55
# 678              56        4.45     broken clouds  2021-11-04 19:28:55
# 679              40        3.44        light rain  2021-11-04 19:28:55
# 680              83        0.00     broken clouds  2021-11-04 19:28:56
# 681              99       13.09   overcast clouds  2021-11-04 19:28:56
#
# [682 rows x 10 columns]
